# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = sns.load_dataset("iris")
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
avg_values = dataset[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].mean()

fig, ax = plt.subplots(figsize=(8, 6))
avg_values.plot(kind='bar', ax=ax, color=['#619CFF', '#F8766D', '#00BA38', '#C77CFF'])

ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=12)
ax.set_ylabel("", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize= (8,4))
sns.countplot(data=dataset, x="species", hue="species")

ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=14)
ax.set_ylabel("", fontsize=14)
ax.grid(True)

plt.tight_layout()
plt.show()

# %%
species_count = dataset['species'].value_counts()

fig, ax = plt.subplots(figsize=(8, 6))
species_count.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#619CFF', '#F8766D', '#00BA38'])

ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=14)
ax.set_ylabel("", fontsize=14)

plt.tight_layout()
plt.show()

# %%
largest_values = dataset.groupby('species')[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].max()
print("Largest size for each flower's petal and sepal:")
print(largest_values)
# Out:
# Largest size for each flower's petal and sepal:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
largest_values = largest_values.reset_index()
melted_df = largest_values.melt(id_vars="species", var_name="Measurement", value_name="Size")

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=melted_df, x="species", y="Size", hue="Measurement", palette="inferno", ax=ax)

ax.set_title("", fontsize=14)
ax.set_xlabel("", fontsize=14)
ax.set_ylabel("", fontsize=14)

plt.xticks(rotation=0)
plt.legend(title="Measurement")

plt.tight_layout()
plt.show()
